# %%
import face_alignment
import cv2
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
fa = face_alignment.FaceAlignment(face_alignment.LandmarksType.TWO_D, flip_input=False, device='cpu')
# Out:
# Downloading: "https://www.adrianbulat.com/downloads/python-fan/2DFAN4-cd938726ad.zip" to C:\Users\zeyad/.cache\torch\hub\checkpoints\2DFAN4-cd938726ad.zip
# 100%|██████████| 91.9M/91.9M [00:23<00:00, 4.15MB/s]

# %%
img = cv2.imread('data/facial_detect/training/Bianca_Jagger_21.jpg')
keypoints = fa.get_landmarks(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
kp = np.array(keypoints[0])
plt.scatter(kp[:, 0], kp[:, 1])
