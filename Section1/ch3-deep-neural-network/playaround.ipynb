# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
img_gray = cv2.imread("./imgs/test.png")
img_gray = img_gray[50:1000, 80:1100]
img_gray = cv2.cvtColor(img_gray, cv2.COLOR_BGR2GRAY)
img_gray = cv2.resize(img_gray, (10, 10))
plt.imshow(img_gray, cmap='gray')

# %%
img = cv2.imread("./imgs/guy.jpeg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = img[-3:, -3:]
plt.imshow(img)
img
# Out:
# array([[[231, 212, 180],
#         [230, 211, 179],
#         [229, 210, 178]],
#
#        [[232, 213, 181],
#         [231, 212, 180],
#         [230, 211, 179]],
#
#        [[232, 213, 181],
#         [232, 213, 181],
#         [231, 212, 180]]], dtype=uint8)
